# %% [markdown]
# # SQL Project

# %%
import pandas as pd
import sqlite3

path = 'mental_health.sqlite'
database = path

# %%
conn = sqlite3.connect(database)

# %%
tables = pd.read_sql("""SELECT * FROM sqlite_master WHERE type='table';""", conn)
tables
# Out:
#     type      name  tbl_name  rootpage  \
# 0  table    Answer    Answer         2
# 1  table  Question  Question      1434
# 2  table    Survey    Survey      1438
#
#                                                  sql
# 0  CREATE TABLE "Answer" (\n\t"AnswerText" VARCHA...
# 1  CREATE TABLE "Question" (\n\t"questiontext" VA...
# 2  CREATE TABLE "Survey" (\n\t"SurveyID" INTEGER ...

# %%
answers = pd.read_sql("""SELECT * FROM ANSWER;""", conn)
answers
# Out:
#                 AnswerText  SurveyID  UserID  QuestionID
# 0                       37      2014       1           1
# 1                       44      2014       2           1
# 2                       32      2014       3           1
# 3                       31      2014       4           1
# 4                       31      2014       5           1
# ...                    ...       ...     ...         ...
# 236893               Other      2016    2689         117
# 236894             Support      2016    2690         117
# 236895  Back-end Developer      2016    2691         117
# 236896     DevOps/SysAdmin      2016    2692         117
# 236897               Other      2016    2693         117
#
# [236898 rows x 4 columns]

# %%
questions = pd.read_sql("""SELECT * FROM QUESTION;""", conn)
questions
# Out:
#                                           questiontext  questionid
# 0                                    What is your age?           1
# 1                                 What is your gender?           2
# 2                         What country do you live in?           3
# 3    If you live in the United States, which state ...           4
# 4                               Are you self-employed?           5
# ..                                                 ...         ...
# 100  Do you think that team members/co-workers woul...         114
# 101  If yes, what condition(s) have you been diagno...         115
# 102  If maybe, what condition(s) do you believe you...         116
# 103  Which of the following best describes your wor...         117
# 104                              Do you work remotely?         118
#
# [105 rows x 2 columns]

# %%
survey = pd.read_sql("""SELECT * FROM SURVEY;""", conn)
survey
# Out:
#    SurveyID                    Description
# 0      2014  mental health survey for 2014
# 1      2016  mental health survey for 2016
# 2      2017  mental health survey for 2017
# 3      2018  mental health survey for 2018
# 4      2019  mental health survey for 2019

# %% [markdown]
# ##  How many people completed the survey for each year?
#
# The number of respondents increased from 2014 to 2016 but then decreased in the following years.

# %%
query = pd.read_sql("""SELECT 
                        SurveyID,
                        COUNT(distinct UserID) AS people_count,
                        SUM(COUNT(DISTINCT UserID)) OVER (ORDER BY  SurveyID) AS cumulative_total                       
                        FROM Answer
                        GROUP BY SurveyID;""", conn)
query
# Out:
#    SurveyID  people_count  cumulative_total
# 0      2014          1260              1260
# 1      2016          1433              2693
# 2      2017           756              3449
# 3      2018           417              3866
# 4      2019           352              4218

# %%
query = pd.read_sql("""SELECT q.questionid AS QID,
                     q.questiontext AS QTEXT,
                     a.AnswerText AS The_Answer
                    FROM QUESTION q
                    JOIN ANSWER a ON q.questionid = a.QuestionID
                    WHERE q.questionid = 1""", conn)
query
# Out:
#       QID              QTEXT The_Answer
# 0       1  What is your age?         37
# 1       1  What is your age?         44
# 2       1  What is your age?         32
# 3       1  What is your age?         31
# 4       1  What is your age?         31
# ...   ...                ...        ...
# 4213    1  What is your age?         27
# 4214    1  What is your age?         48
# 4215    1  What is your age?         50
# 4216    1  What is your age?         30
# 4217    1  What is your age?         24
#
# [4218 rows x 3 columns]

# %%
query = pd.read_sql("""
    SELECT  
        q.questionid AS QID,
        q.questiontext AS QTEXT,
        COUNT(a.UserID) AS people_count,
        CAST(a.AnswerText AS SIGNED) AS Age
    FROM QUESTION q
    JOIN ANSWER a ON q.questionid = a.QuestionID
    WHERE q.questionid = 1 
      AND CAST(a.AnswerText AS SIGNED) BETWEEN 0 AND 75
    GROUP BY q.questionid, q.questiontext, Age
    order by people_count DESC;
""", conn)
query
# Out:
#     QID              QTEXT  people_count  Age
# 0     1  What is your age?           250   30
# 1     1  What is your age?           229   29
# 2     1  What is your age?           227   32
# 3     1  What is your age?           223   31
# 4     1  What is your age?           220   28
# 5     1  What is your age?           202   34
# 6     1  What is your age?           201   33
# 7     1  What is your age?           201   35
# 8     1  What is your age?           197   27
# 9     1  What is your age?           194   26
# 10    1  What is your age?           184   37
# 11    1  What is your age?           160   38
# 12    1  What is your age?           147   25
# 13    1  What is your age?           147   36
# 14    1  What is your age?           137   39
# 15    1  What is your age?           128   24
# 16    1  What is your age?           122   40
# 17    1  What is your age?           107   23
# 18    1  What is your age?           100   42
# 19    1  What is your age?            88   41
# 20    1  What is your age?            82   43
# 21    1  What is your age?            74   22
# 22    1  What is your age?            74   45
# 23    1  What is your age?            68   44
# 24    1  What is your age?            58   46
# 25    1  What is your age?            39   21
# 26    1  What is your age?            38   47
# 27    1  What is your age?            36   49
# 28    1  What is your age?            30   50
# 29    1  What is your age?            29   48
# 30    1  What is your age?            22   51
# 31    1  What is your age?            22   55
# 32    1  What is your age?            20   19
# 33    1  What is your age?            17   20
# 34    1  What is your age?            17   52
# 35    1  What is your age?            17   54
# 36    1  What is your age?            15   53
# 37    1  What is your age?            14   57
# 38    1  What is your age?            13   56
# 39    1  What is your age?             9   18
# 40    1  What is your age?             7   61
# 41    1  What is your age?             6   59
# 42    1  What is your age?             5   58
# 43    1  What is your age?             5   60
# 44    1  What is your age?             5   63
# 45    1  What is your age?             3   62
# 46    1  What is your age?             3   64
# 47    1  What is your age?             3   65
# 48    1  What is your age?             2   66
# 49    1  What is your age?             2   67
# 50    1  What is your age?             1    0
# 51    1  What is your age?             1    3
# 52    1  What is your age?             1    5
# 53    1  What is your age?             1    8
# 54    1  What is your age?             1   11
# 55    1  What is your age?             1   15
# 56    1  What is your age?             1   17
# 57    1  What is your age?             1   70
# 58    1  What is your age?             1   72
# 59    1  What is your age?             1   74

# %%
import matplotlib.pyplot as plt
query['Age'] = pd.to_numeric(query['Age'], errors='coerce')
query = query.dropna(subset=['Age'])

age_distribution = query.groupby('Age')['people_count'].sum().reset_index()

plt.figure(figsize=(12, 8))
plt.bar(age_distribution['Age'], age_distribution['people_count'], color='skyblue', edgecolor='black')

plt.title('Age Distribution Based on People Count', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Number of People', fontsize=14)

plt.xticks(ticks=range(0, int(age_distribution['Age'].max()) + 5, 5), fontsize=10, rotation=45)

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
#query['Age'] = pd.to_numeric(query['Age'], errors='coerce') 
query = query.dropna(subset=['Age']) 
plt.figure(figsize=(10, 6)) 
plt.hist(query['Age'], bins=10, color='skyblue', edgecolor='black')

plt.xticks(ticks=range(0, int(query['Age'].max()) + 1, 5), fontsize=10)
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

plt.grid(axis='y', linestyle='--', alpha=0.7) 
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### In the cell below it indicates that there is no null values in the Answer Table.

# %%
query = pd.read_sql("""SELECT * FROM ANSWER WHERE AnswerText IS NULL""", conn)
query
# Out:
# Empty DataFrame
# Columns: [AnswerText, SurveyID, UserID, QuestionID]
# Index: []

# %%
query = pd.read_sql("""SELECT QuestionID,
                        COUNT(QuestionID) As NumOfAnswers
                        FROM ANSWER 
                        GROUP BY QuestionID""", conn)
query
# Out:
#      QuestionID  NumOfAnswers
# 0             1          4218
# 1             2          4218
# 2             3          4218
# 3             4          4218
# 4             5          4218
# ..          ...           ...
# 100         114          1433
# 101         115          2072
# 102         116          1793
# 103         117          2692
# 104         118          1433
#
# [105 rows x 2 columns]

# %%
query = pd.read_sql("""SELECT A.QuestionID, Q.questiontext 
            FROM ANSWER A
            join Question Q on  A.QuestionID=  Q.QuestionID
            GROUP BY A.QuestionID
            HAVING COUNT(DISTINCT SurveyID)  = 5 
               ORDER BY A.QuestionID;
                        """, conn)
query
# Out:
#     QuestionID                                       questiontext
# 0            1                                  What is your age?
# 1            2                               What is your gender?
# 2            3                       What country do you live in?
# 3            4  If you live in the United States, which state ...
# 4            5                             Are you self-employed?
# 5            6    Do you have a family history of mental illness?
# 6            7  Have you ever sought treatment for a mental he...
# 7            8  How many employees does your company or organi...
# 8            9  Is your employer primarily a tech company/orga...
# 9           10  Does your employer provide mental health benef...
# 10          11  Is your anonymity protected if you choose to t...
# 11          12  Would you bring up a mental health issue with ...

# %% [markdown]
# We noticed that there is a mismatching with questionID and the number of the rows where it supposed to be the 105 questionIDs from 1 to 105, and the change comes from 34 and jumped to 48

# %% [markdown]
# ## How many questions were there for each year?

# %%
query = pd.read_sql("""SELECT s.SurveyID,
                    COUNT(DISTINCT(a.QuestionID)) AS NumOfQuestions
                    FROM Survey s
                    JOIN ANSWER a ON a.SurveyID = s.SurveyID
                    GROUP BY a.SurveyID""", conn)
query
# Out:
#    SurveyID  NumOfQuestions
# 0      2014              26
# 1      2016              60
# 2      2017              76
# 3      2018              76
# 4      2019              76

# %% [markdown]
# ## how many unique people answered each question?
# ### (From the least answered  To the highest answered )

# %%
query = pd.read_sql("""SELECT 
                        QuestionID ,
                        count( distinct UserID) AS people_answered
                           
                        FROM Answer
                        GROUP BY QuestionID
                        ORDER BY people_answered ASC;""", conn)
query
# Out:
#      QuestionID  people_answered
# 0            92             1260
# 1            93             1260
# 2            94             1260
# 3            95             1260
# 4            96             1260
# ..          ...              ...
# 100           8             4218
# 101           9             4218
# 102          10             4218
# 103          11             4218
# 104          12             4218
#
# [105 rows x 2 columns]

# %% [markdown]
# In 2014 there are less questions due to some reason

# %%
query = pd.read_sql("""SELECT DISTINCT(q.questionid),q.questiontext
                    FROM QUESTION q
                    JOIN ANSWER a ON q.questionid = a.QuestionID
                    WHERE a.SurveyID = 2014""", conn)
query
# Out:
#     questionid                                       questiontext
# 0            1                                  What is your age?
# 1            2                               What is your gender?
# 2            3                       What country do you live in?
# 3            4  If you live in the United States, which state ...
# 4            5                             Are you self-employed?
# 5            6    Do you have a family history of mental illness?
# 6            7  Have you ever sought treatment for a mental he...
# 7            8  How many employees does your company or organi...
# 8            9  Is your employer primarily a tech company/orga...
# 9           10  Does your employer provide mental health benef...
# 10          11  Is your anonymity protected if you choose to t...
# 11          12  Would you bring up a mental health issue with ...
# 12          90  Do you think that discussing a physical health...
# 13          91  Do you feel that your employer takes mental he...
# 14          92  If you have a mental health condition, do you ...
# 15          93  Do you work remotely (outside of an office) at...
# 16          94  Do you know the options for mental health care...
# 17          95  Has your employer ever discussed mental health...
# 18          96  Does your employer provide resources to learn ...
# 19          97  How easy is it for you to take medical leave f...
# 20          98  Do you think that discussing a mental health i...
# 21          99  Would you be willing to discuss a mental healt...
# 22         100  Would you be willing to discuss a mental healt...
# 23         101  Would you bring up a physical health issue wit...
# 24         102  Have you heard of or observed negative consequ...
# 25         103                   Any additional notes or comments

# %%
query = pd.read_sql("""SELECT AnswerText 
                       FROM ANSWER 
                       WHERE SurveyID = 2014 AND QuestionID = 1""", conn)
query['AnswerText'].astype('Int32').mean()
# Out:
# 32.13492063492063

# %%
survey14 = pd.read_sql("""SELECT a.UserID AS "User ID",
                              q.questionid AS "Question ID",
                              q.questiontext AS "Question",
                              a.AnswerText AS "Answer"
                       FROM ANSWER a 
                       JOIN QUESTION q ON q.questionid = a.QuestionID
                       WHERE a.SurveyID = 2014
                       """, conn)
survey14
# Out:
#        User ID  Question ID                          Question Answer
# 0            1            1                 What is your age?     37
# 1            2            1                 What is your age?     44
# 2            3            1                 What is your age?     32
# 3            4            1                 What is your age?     31
# 4            5            1                 What is your age?     31
# ...        ...          ...                               ...    ...
# 32755     1256          103  Any additional notes or comments     -1
# 32756     1257          103  Any additional notes or comments     -1
# 32757     1258          103  Any additional notes or comments     -1
# 32758     1259          103  Any additional notes or comments     -1
# 32759     1260          103  Any additional notes or comments     -1
#
# [32760 rows x 4 columns]

# %%
pd.set_option('display.max_colwidth', 100)

# %%
mode_values = survey14.groupby('Question')['Answer'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None)
mode_values = mode_values.reset_index()

mode_values.columns = ['Question', 'Most frquent Answer']

mode_values.sort_values(by='Question')
# Out:
#                                                                                                Question  \
# 0                                                                      Any additional notes or comments
# 1                                                                                Are you self-employed?
# 2                   Do you feel that your employer takes mental health as seriously as physical health?
# 3                                                       Do you have a family history of mental illness?
# 4                                Do you know the options for mental health care your employer provides?
# 5   Do you think that discussing a mental health issue with your employer would have negative conseq...
# 6   Do you think that discussing a physical health issue with your employer would have negative cons...
# 7                                 Do you work remotely (outside of an office) at least 50% of the time?
# 8                     Does your employer provide mental health benefits as part of healthcare coverage?
# 9   Does your employer provide resources to learn more about mental health issues and how to seek help?
# 10              Has your employer ever discussed mental health as part of an employee wellness program?
# 11       Have you ever sought treatment for a mental health disorder from a mental health professional?
# 12  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 13                          How easy is it for you to take medical leave for a mental health condition?
# 14                                           How many employees does your company or organization have?
# 15                If you have a mental health condition, do you feel that it interferes with your work?
# 16                           If you live in the United States, which state or territory do you live in?
# 17  Is your anonymity protected if you choose to take advantage of mental health or substance abuse ...
# 18                                              Is your employer primarily a tech company/organization?
# 19                                                                         What country do you live in?
# 20                                                                                    What is your age?
# 21                                                                                 What is your gender?
# 22                           Would you be willing to discuss a mental health issue with your coworkers?
# 23                Would you be willing to discuss a mental health issue with your direct supervisor(s)?
# 24                  Would you bring up a mental health issue with a potential employer in an interview?
# 25                Would you bring up a physical health issue with a potential employer in an interview?
#
#    Most frquent Answer
# 0                   -1
# 1                    0
# 2           Don't know
# 3                   No
# 4                   No
# 5                   No
# 6                   No
# 7                   No
# 8                  Yes
# 9                   No
# 10                  No
# 11                   1
# 12                  No
# 13          Don't know
# 14                6-25
# 15           Sometimes
# 16                  -1
# 17          Don't know
# 18                   1
# 19       United States
# 20                  29
# 21                Male
# 22        Some of them
# 23                 Yes
# 24                  No
# 25               Maybe

# %% [markdown]
# ### there is something odd about this dataset, How come the most frequent answer to the question "What country do you live in?" is United States, and the question "If you live in the United States, which state  do you live in?" is -1?
#
# so we dive in to know the actual answer

# %%
query = pd.read_sql("""SELECT Answer,COUNT(Answer) AS frequency
                    FROM (SELECT a.UserID AS "User  ID",
                    q.questionid AS "Question ID",
                    q.questiontext AS "Question",
                    a.AnswerText AS "Answer"
                FROM ANSWER a 
                JOIN QUESTION q ON q.questionid = a.QuestionID
                WHERE a.SurveyID = 2014
                        ) AS AnswerData WHERE "Question ID" = 4
                    GROUP BY Answer
                    ORDER BY frequency DESC""", conn)
query
# Out:
#             Answer  frequency
# 0               -1        516
# 1       California        138
# 2       Washington         70
# 3         New York         57
# 4        Tennessee         45
# 5            Texas         44
# 6             Ohio         30
# 7     Pennsylvania         29
# 8           Oregon         29
# 9         Illinois         29
# 10         Indiana         27
# 11        Michigan         22
# 12       Minnesota         21
# 13   Massachusetts         20
# 14         Florida         15
# 15        Virginia         14
# 16  North Carolina         14
# 17       Wisconsin         12
# 18        Missouri         12
# 19         Georgia         12
# 20            Utah         11
# 21        Colorado          9
# 22        Maryland          8
# 23         Alabama          8
# 24         Arizona          7
# 25        Oklahoma          6
# 26      New Jersey          6
# 27  South Carolina          5
# 28        Kentucky          5
# 29            Iowa          4
# 30              DC          4
# 31     Connecticut          4
# 32         Vermont          3
# 33    South Dakota          3
# 34   New Hampshire          3
# 35          Nevada          3
# 36          Kansas          3
# 37         Wyoming          2
# 38      New Mexico          2
# 39        Nebraska          2
# 40   West Virginia          1
# 41    Rhode Island          1
# 42     Mississippi          1
# 43           Maine          1
# 44       Louisiana          1
# 45           Idaho          1

# %%
import matplotlib.pyplot as plt
query[0:4].plot(kind='bar', x='Answer', y='frequency', color=['black', 'blue','blue','blue'], legend=False)

plt.title('Most Frequent States in the Survey of 2014')
plt.xlabel('State')
plt.ylabel('Frequncy')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# so from the above query we noticed that California is actually the most frequent state that this survey placed on

# %% [markdown]
# ok lets dive into this question "If you have a mental health condition, do you feel that it interferes with your work?"
# and plot the result

# %%
query = pd.read_sql("""SELECT a.UserID AS "User ID",
                              q.questionid AS "Question ID",
                              q.questiontext AS "Question",
                              a.AnswerText AS "Answer"
                       FROM ANSWER a 
                       JOIN QUESTION q ON q.questionid = a.QuestionID
                       WHERE a.SurveyID = 2014 AND q.questionid = 92""", conn)
query
# Out:
#       User ID  Question ID  \
# 0           1           92
# 1           2           92
# 2           3           92
# 3           4           92
# 4           5           92
# ...       ...          ...
# 1255     1256           92
# 1256     1257           92
# 1257     1258           92
# 1258     1259           92
# 1259     1260           92
#
#                                                                                    Question  \
# 0     If you have a mental health condition, do you feel that it interferes with your work?
# 1     If you have a mental health condition, do you feel that it interferes with your work?
# 2     If you have a mental health condition, do you feel that it interferes with your work?
# 3     If you have a mental health condition, do you feel that it interferes with your work?
# 4     If you have a mental health condition, do you feel that it interferes with your work?
# ...                                                                                     ...
# 1255  If you have a mental health condition, do you feel that it interferes with your work?
# 1256  If you have a mental health condition, do you feel that it interferes with your work?
# 1257  If you have a mental health condition, do you feel that it interferes with your work?
# 1258  If you have a mental health condition, do you feel that it interferes with your work?
# 1259  If you have a mental health condition, do you feel that it interferes with your work?
#
#          Answer
# 0         Often
# 1        Rarely
# 2        Rarely
# 3         Often
# 4         Never
# ...         ...
# 1255      Often
# 1256  Sometimes
# 1257         -1
# 1258  Sometimes
# 1259  Sometimes
#
# [1260 rows x 4 columns]

# %%
query['Answer'].value_counts().plot(kind='bar', color=['skyblue','black','skyblue','skyblue','skyblue'])
plt.show()

# %% [markdown]
# so most people said 'Sometimes', ok then.

# %% [markdown]
# let's see this query about question "Have you heard of or observed negative consequences for coworkers with mental health conditions?"

# %%
query = pd.read_sql("""SELECT a.UserID AS "User ID",
                              q.questionid AS "Question ID",
                              q.questiontext AS "Question",
                              a.AnswerText AS "Answer"
                       FROM ANSWER a 
                       JOIN QUESTION q ON q.questionid = a.QuestionID
                       WHERE a.SurveyID = 2014 AND q.questionid = 102""",conn)
query
# Out:
#       User ID  Question ID  \
# 0           1          102
# 1           2          102
# 2           3          102
# 3           4          102
# 4           5          102
# ...       ...          ...
# 1255     1256          102
# 1256     1257          102
# 1257     1258          102
# 1258     1259          102
# 1259     1260          102
#
#                                                                                                  Question  \
# 0     Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 1     Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 2     Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 3     Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 4     Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# ...                                                                                                   ...
# 1255  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 1256  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 1257  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 1258  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
# 1259  Have you heard of or observed negative consequences for coworkers with mental health conditions ...
#
#      Answer
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4        No
# ...     ...
# 1255     No
# 1256     No
# 1257     No
# 1258     No
# 1259    Yes
#
# [1260 rows x 4 columns]

# %%
query['Answer'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Answer'>

# %% [markdown]
# as we noticed here, most people said 'No', that means that most people don't know actually how a serious mental health condition affect the perofromance of the workers, hence that people answerd the question about themselves "If you have a mental health condition, do you feel that it interferes with your work?" most of them said 'Sometimes'!!
# So, the answer is that most people don't know how a serious mental health condition could affect a person
